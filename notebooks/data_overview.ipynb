# %%
import amber_utils.io_utils as io
import viz.data_viz as vp

# %load_ext autoreload
# %autoreload 2

# %%
gen_kwargs = dict(
    save=True, 
)

# %%
df = io.load_results_df('all_results')
df

# %% [markdown]
# # Group level

# %% [markdown]
# ## Trials count

# %%
vp.plot_trial_differences(df, **gen_kwargs)

# %% [markdown]
# ## Accuracy

# %%
vp.plot_feature_overview(df, feature_col='acc', plot_style='violin', **gen_kwargs)
vp.plot_feature_overview(df, feature_col='acc', plot_style='box-outliers', **gen_kwargs)
vp.plot_feature_overview(df, feature_col='acc', plot_style='box-no_outliers', **gen_kwargs)

# %%
vp.plot_distribution_overview(df, feature_col='acc', **gen_kwargs)

# %% [markdown]
# ## Reaction time
# ### Mean

# %%
vp.plot_feature_overview(df, feature_col='rt_mean', plot_style='violin', **gen_kwargs)
vp.plot_feature_overview(df, feature_col='rt_mean', plot_style='box-outliers', **gen_kwargs)
vp.plot_feature_overview(df, feature_col='rt_mean', plot_style='box-no_outliers', **gen_kwargs)

# %%
vp.plot_distribution_overview(df, feature_col='rt_mean', **gen_kwargs)

# %% [markdown]
# ### Median

# %%
vp.plot_feature_overview(df, feature_col='rt_med', plot_style='violin', **gen_kwargs)
vp.plot_feature_overview(df, feature_col='rt_med', plot_style='box-outliers', **gen_kwargs)
vp.plot_feature_overview(df, feature_col='rt_med', plot_style='box-no_outliers', **gen_kwargs)

# %%
vp.plot_distribution_overview(df, feature_col='rt_med', **gen_kwargs)

# %% [markdown]
# # Participant level

# %%
vp.plot_each_sid_distribution_overview(df, feature_col='acc', **gen_kwargs)
vp.plot_each_sid_distribution_overview(df, feature_col='rt_mean', **gen_kwargs)
vp.plot_each_sid_distribution_overview(df, feature_col='rt_med', **gen_kwargs)
